# %% [markdown]
# # Globla Minimum Variance Portfolio & Equal Weight Portfolio #

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import risk_kit as rk
import numpy as np
from scipy.optimize import minimize


ind = rk.get_ind_returns()
er = rk.annualize_rets(ind["1996":"2000"], 12)
cov = ind["1996":"2000"].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
l = ["Food","Steel"]
rk.msr(0.10, er[l], cov.loc[l, l])
# Out:
# array([0.75040363, 0.24959637])

# %%
er[l]
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %%
rk.msr(0.1, np.array([.11, .12]), cov.loc[l, l])
# Out:
# array([0.57930354, 0.42069646])

# %%
rk.msr(0.1, np.array([.10, .13]), cov.loc[l, l])
# Out:
# array([0., 1.])

# %%
rk.plot_ef(20, er, cov, show_cml=True, riskfree_rate=0.10, show_ew=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
rk.plot_ef(20, er, cov, show_cml=True, riskfree_rate=0.10, show_ew=True, show_gmv=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>
